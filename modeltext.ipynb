# %%
import pandas as pd
from pycaret.nlp import *

# %%
df = pd.read_csv("BBC News Train.csv")

# %%
import chart_studio
from chart_studio import plotly
# Out:
#             <script src="/static/components/requirejs/require.js"></script>
#             <script>
#               requirejs.config({
#                 paths: {
#                   base: '/static/base',
#                   plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#                 },
#               });
#             </script>

# %%
df.head()
# Out:
#    ArticleId                                               Text  Category
# 0       1833  worldcom ex-boss launches defence lawyers defe...  business
# 1        154  german business confidence slides german busin...  business
# 2       1101  bbc poll indicates economic gloom citizens in ...  business
# 3       1976  lifestyle  governs mobile choice  faster  bett...      tech
# 4        917  enron bosses in $168m payout eighteen former e...  business

# %%
exp_nlp102 = setup(data = df, target = 'Text', session_id = 123)
# Out:
# <style  type="text/css" >
# </style><table id="T_4af4a748_b5fe_11ea_b541_1063c84bb036" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_4af4a748_b5fe_11ea_b541_1063c84bb036row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_4af4a748_b5fe_11ea_b541_1063c84bb036row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                                 <td id="T_4af4a748_b5fe_11ea_b541_1063c84bb036row1_col0" class="data row1 col0" ># Documents</td>
#                         <td id="T_4af4a748_b5fe_11ea_b541_1063c84bb036row1_col1" class="data row1 col1" >1490</td>
#             </tr>
#             <tr>
#                                 <td id="T_4af4a748_b5fe_11ea_b541_1063c84bb036row2_col0" class="data row2 col0" >Vocab Size</td>
#                         <td id="T_4af4a748_b5fe_11ea_b541_1063c84bb036row2_col1" class="data row2 col1" >13243</td>
#             </tr>
#             <tr>
#                                 <td id="T_4af4a748_b5fe_11ea_b541_1063c84bb036row3_col0" class="data row3 col0" >Custom Stopwords</td>
#                         <td id="T_4af4a748_b5fe_11ea_b541_1063c84bb036row3_col1" class="data row3 col1" >False</td>
#             </tr>
#     </tbody></table>

# %%
lda = create_model('lda')

# %%
plot_model(plot = 'bigram')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="200c00a4-5f52-4d1b-999b-93f0315b0c4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("200c00a4-5f52-4d1b-999b-93f0315b0c4d")) {
#                     Plotly.newPlot(
#                         '200c00a4-5f52-4d1b-999b-93f0315b0c4d',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "count", "orientation": "v", "text": "", "type": "bar", "x": ["last year", "say would", "spokesman say", "last week", "first time", "say say", "last month", "next year", "also say", "year say", "analyst say", "take place", "say want", "next week", "take part", "say statement", "say also", "say plan", "let people", "say think", "company say", "firm say", "people say", "report say", "people use", "next month", "many people", "government say", "say go", "half time", "good film", "say people", "say analyst", "say make", "time say", "say could", "say government", "say add", "go sale", "young people", "say new", "would make", "music player", "say hope", "public service", "would also", "well know", "say expect", "say report", "say many", "video game", "say good", "digital music", "first half", "say look", "statement say", "week say", "people want", "recent year", "could use", "figure show", "new year", "say take", "take action", "film maker", "end year", "go back", "make clear", "could also", "later year", "early year", "good director", "would take", "local government", "number people", "play game", "police say", "also include", "world number", "good actor", "next election", "tory say", "work hard", "early week", "previous year", "would put", "come back", "come year", "would mean", "say feel", "say see", "make easy", "make film", "take advantage", "time year", "would help", "would allow", "would give", "say get", "well say"], "y": [318, 204, 119, 114, 108, 107, 100, 86, 82, 71, 70, 64, 61, 59, 55, 51, 51, 51, 49, 49, 47, 46, 46, 44, 44, 44, 42, 42, 42, 41, 41, 41, 41, 41, 40, 40, 39, 39, 39, 39, 39, 39, 37, 36, 36, 36, 36, 36, 33, 32, 31, 31, 31, 31, 31, 30, 30, 30, 30, 30, 29, 29, 29, 28, 28, 28, 28, 28, 28, 28, 27, 27, 27, 27, 27, 27, 27, 27, 26, 26, 26, 26, 26, 26, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 25, 24, 24, 24, 24]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {" ...

# %%
plot_model()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="322963cc-700f-4553-9a2f-22f6e94dc0d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("322963cc-700f-4553-9a2f-22f6e94dc0d2")) {
#                     Plotly.newPlot(
#                         '322963cc-700f-4553-9a2f-22f6e94dc0d2',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "count", "orientation": "v", "text": "", "type": "bar", "x": ["say", "year", "would", "make", "also", "people", "take", "go", "could", "time", "new", "use", "good", "last", "first", "game", "come", "government", "get", "see", "play", "work", "firm", "show", "well", "give", "film", "company", "add", "number", "may", "want", "win", "include", "world", "many", "plan", "think", "set", "player", "way", "week", "service", "country", "month", "big", "look", "call", "need", "back", "music", "market", "help", "know", "sale", "expect", "report", "still", "end", "offer", "start", "top", "day", "find", "rise", "lead", "tell", "put", "technology", "second", "next", "claim", "try", "much", "hold", "part", "record", "move", "share", "pay", "become", "early", "increase", "run", "high", "believe", "follow", "election", "labour", "place", "however", "face", "already", "issue", "lose", "change", "home", "business", "hit", "right"], "y": [5867, 1813, 1712, 1460, 1426, 1324, 1156, 1131, 1032, 1010, 966, 966, 919, 905, 859, 838, 773, 767, 749, 747, 737, 676, 660, 656, 656, 651, 647, 646, 608, 601, 600, 597, 582, 580, 564, 562, 540, 530, 524, 518, 508, 506, 503, 502, 497, 490, 489, 488, 487, 484, 475, 470, 469, 463, 452, 432, 422, 421, 418, 415, 409, 407, 403, 403, 396, 395, 395, 394, 394, 392, 391, 391, 391, 386, 385, 384, 372, 371, 368, 365, 360, 359, 358, 352, 347, 342, 339, 337, 334, 333, 331, 322, 320, 319, 313, 313, 313, 311, 310, 309]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {" ...

# %%
plot_model(lda, plot = 'topic_distribution')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="7acb1c2d-622b-47f5-986b-8a26091ca5c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7acb1c2d-622b-47f5-986b-8a26091ca5c6")) {
#                     Plotly.newPlot(
#                         '7acb1c2d-622b-47f5-986b-8a26091ca5c6',
#                         [{"alignmentgroup": "True", "customdata": [["say, use, people, technology, service, make, user, also, net, could"], ["film, year, say, good, also, show, include, music, award, top"], ["say, game, play, go, win, time, make, first, take, get"], ["say, would, year, government, also, people, could, make, plan, country"]], "hovertemplate": "Topic=%{x}<br>Documents=%{y}<br>Keyword=%{customdata[0]}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Topic 0", "Topic 1", "Topic 2", "Topic 3"], "xaxis": "x", "y": [237, 247, 362, 644], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
tuned_unsupervised = tune_model(model = 'lda', multi_core = True)
# Out:
# IntProgress(value=0, description='Processing: ', max=25)
# Output()
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="40e7f471-6c73-427b-897c-a4767cc62559" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("40e7f471-6c73-427b-897c-a4767cc62559")) {
#                     Plotly.newPlot(
#                         '40e7f471-6c73-427b-897c-a4767cc62559',
#                         [{"hovertemplate": "Metric=Coherence<br># Topics=%{x}<br>Score=%{y}<extra></extra>", "legendgroup": "Coherence", "line": {"color": "#636efa", "dash": "solid", "shape": "linear"}, "mode": "lines", "name": "Coherence", "orientation": "v", "showlegend": true, "type": "scatter", "x": [2, 4, 8, 16, 32, 64, 100, 200, 300, 400], "xaxis": "x", "y": [0.3023809854607977, 0.34712256542734965, 0.4155823224633719, 0.37883279663311986, 0.41107668677474973, 0.3805133881323902, 0.3642155812509921, 0.3738336320855317, 0.3611769188805284, 0.3684331856983215], "yaxis": "y"}],
#                         {"legend": {"title": {"text": "Metric"}, "tracegroupgap": 0}, "plot_bgcolor": "rgb(245,245,245)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewi ...
# Best Model: Latent Dirichlet Allocation | # Topics: 8 | Coherence: 0.4156

# %%
plot_model(lda, plot = 'tsne')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="577c52ec-729a-49ab-b68f-f4816f319337" class="plotly-graph-div" style="height:800px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("577c52ec-729a-49ab-b68f-f4816f319337")) {
#                     Plotly.newPlot(
#                         '577c52ec-729a-49ab-b68f-f4816f319337',
#                         [{"hovertemplate": "Dominant_Topic=Topic 0<br>0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>", "legendgroup": "Topic 0", "marker": {"color": "#636efa", "opacity": 0.7, "symbol": "circle"}, "mode": "markers", "name": "Topic 0", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [15.813053131103516, 11.298171997070312, 11.263416290283203, 18.355085372924805, 15.573626518249512, 10.03591251373291, 13.307037353515625, 13.517513275146484, 17.16016960144043, 14.020394325256348, 7.56010627746582, 9.394586563110352, 12.976123809814453, 10.898543357849121, 12.986444473266602, 11.728372573852539, 9.142477989196777, 12.699396133422852, 18.411373138427734, 8.600022315979004, 13.001537322998047, 14.879645347595215, 14.942586898803711, 10.57706069946289, 11.5138521194458, 12.157325744628906, 7.4948296546936035, 17.74763298034668, 15.673104286193848, 15.13509464263916, 11.037614822387695, 18.411325454711914, 12.910785675048828, 14.660577774047852, 17.14397430419922, 13.635209083557129, 18.724464416503906, 14.350628852844238, 11.199073791503906, 15.818337440490723, 18.726106643676758, 15.119362831115723, 11.926628112792969, 11.464101791381836, 9.401522636413574, 7.3211989402771, 18.19886589050293, 10.719134330749512, 7.606804847717285, 10.850163459777832, 13.736751556396484, 14.904664993286133, 13.068854331970215, 12.78780460357666, 18.794509887695312, 10.902931213378906, 12.90262222290039, 14.719399452209473, 18.26207733154297, 14.719436645507812, 13.702662467956543, 11.325618743896484, 13.863261222839355, 15.813017845153809, 12.026616096496582, 19.054569244384766, 13.501197814941406, 13.552167892456055, 14.905848503112793, 14.434711456298828, 13.15535831451416, 17.593769073486328, 10.89937973022461, 14.030143737792969, 11.298187255859375, 16.131134033203125, 13.205005645751953, 8.856072425842285, 14.794499397277832, 10.70504093170166, 16.458480834960938, 12.613667488098145, 9.984823226928711, 19.15871810913086, 13.940099716186523, 7.574865341186523, 9.077683448791504, 18.314403533935547, 16.511091232299805, 11.125874519348145, 7.782501220703125, 7.485541343688965, 18.788341522216797, 10.520821571350098, 14.878988265991211, 10.850174903869629, 12.449542999267578, 11.06983470916748, 8.659647941589355, 18.688350677490234, 13.907021522521973, 14.735627174377441, 15.63589859008789, 19.226688385009766, 16.283985137939453, 13.90705394744873, 7.336833953857422, 11.699871063232422, 11.44955825805664, 19.141254425048828, 18.198989868164062, 11.69987964630127, 10.951471328735352, 15.759050369262695, 13.549524307250977, 15.303890228271484, 18.699893951416016, 16.63910675048828, 17.715593338012695, 13.450875282287598, 16.751577377319336, 15.414284706115723, 18.632795333862305, 13.338922500610352, 15.355443954467773, 16.836034774780273, 18.95713233947754, 10.902896881103516, 15.365496635437012, 7.199957370758057, 18.476655960083008, 10.75223159790039, 18.539735794067383, 19.03214454650879, 16.191686630249023, 17.72357940673828, 14.365994453430176, 11.462328910827637, 17.116199493408203, 10.091897964477539, 7.454089164733887, 10.500596046447754, 12.157357215881348, 16.639179229736328, 18.473161697387695, 12.612879753112793, 12.613039016723633, 9.721667289733887, 19.2266902923584, 11.4414701461792, 7.0015997886657715, 18.794504165649414, 18.156461715698242, 10.705041885375977, 15.63625431060791, 14.366141319274902, 18.604267120361328, 14.049970626831055, 9.211808204650879, 9.837690353393555, 19.227188110351562, 17.684677124023438, 14.108687400817871, 18.855844497680664, 15.519120216369629, 14.132399559020996, 17.107885360717773, 16.65651512145996, 12.949344635009766, 17.148487091064453, 8.794408798217773, 14.485797882080078, 14.73564624786377, 16.131681442260742, 10.928260803222656, 17.080524444580078, 18.150054931640625, 11.844077110290527, 11.644850730895996, 14.918680191040039, 16.65663719177246, 19.159549713134766, 10.90324878692627, 16.10772705078125, 9.174150466918945, 13.192292213439941, 13.796429634094238, 10.0501680 ...

# %%
plot_model(lda, plot = 'umap')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
evaluate_model(lda)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Frequency Plot', 'freque…

# %%
save_experiment('Experiment_123 08Feb2020')
# Out:
# Experiment Succesfully Saved

# %%
saved_experiment = load_experiment('Experiment_123 08Feb2020')
# Out:
#                         Object
# 0                         Info
# 1                      Dataset
# 2                       Corpus
# 3                   Dictionary
# 4                         Text
# 5  Latent Dirichlet Allocation
# 6                   Best Model
# 7                   Best Model

# %%
saved_lda = saved_experiment[4]

# %%
print(saved_lda)
# Out:
# [['launch', 'defence', 'lawyer', 'defend', 'former', 'battery', 'fraud', 'charge', 'call', 'company', 'whistleblower', 'internal', 'accounting', 'alert', 'director', 'irregular', 'accounting', 'practice', 'telecom', 'giant', 'warning', 'lead', 'collapse', 'firm', 'follow', 'bn', 'accounting', 'fraud', 'mr_ebber', 'pleaded_guilty_charge', 'fraud', 'conspiracy', 'prosecution', 'lawyer', 'argue', 'orchestrate', 'series', 'trick', 'order', 'employee', 'hide', 'expense', 'inflate', 'revenue', 'meet', 'earning', 'estimate', 'run', 'business', 'tell', 'jury', 'auditor', 'approve', 'early', 'say', 'give', 'green', 'light', 'procedure', 'practice', 'use', 'lawyer', 'say', 'unaware', 'fraud', 'argue', 'auditor', 'alert', 'problem', 'also', 'say', 'shareholder', 'meeting', 'often', 'pass', 'technical', 'question', 'company', 'finance', 'chief', 'give', 'brief', 'answer', 'prosecution', 'former', 'say', 'order', 'accounting', 'adjustment', 'firm', 'tell', 'hit', 'book', 'however', 'say', 'mention', 'uncomfortable', 'meeting', 'could', 'face', 'jail', 'sentence', 'year', 'convict', 'charge', 'face', 'know', 'last', 'week', 'agree', 'deal', 'value'], ['german', 'business', 'confidence', 'slide', 'german', 'business', 'confidence', 'fall', 'hope', 'speedy', 'large', 'economy', 'say', 'index', 'fall', 'decline', 'month', 'study', 'find', 'outlook', 'manufacture', 'retail', 'sector', 'worsen', 'observer', 'hope', 'confident', 'business', 'sector', 'would', 'signal', 'economic_activity', 'pick', 'surprised', 'index', 'take', 'say', 'economist', 'main', 'reason', 'probably', 'domestic', 'economy', 'still', 'weak', 'particularly', 'retail', 'trade', 'economy', 'call', 'confidence', 'figure', 'mild', 'decline', 'say', 'retreat', 'index', 'remain', 'relatively', 'high', 'level', 'expect', 'modest', 'economic', 'upswing', 'economy', 'grow', 'last', 'year', 'shrink', 'however', 'economy', 'contract', 'last', 'month', 'mainly', 'due', 'reluctance', 'consumer', 'spend', 'late', 'indication', 'growth', 'still', 'prove', 'elusive', 'say', 'improvement', 'german', 'sluggish', 'export', 'keep', 'thing', 'go', 'first', 'half', 'demand', 'export', 'hit', 'value', 'hit', 'record', 'level', 'make', 'german', 'product', 'less', 'competitive', 'overseas', 'top', 'stick', 'close', 'manufacturing', 'firm', 'include', 'negotiate', 'union', 'cost_cutting_measure', 'analyst', 'say', 'figure', 'continue', 'problem', 'may', 'delay', 'rise', 'european', 'eurozone', 'comment', 'senior', 'official', 'recently', 'focus', 'threat', 'inflation', 'prompt', 'fear', 'may', 'rise'], ['indicate', 'economic', 'gloom', 'citizen', 'nation', 'survey', 'believe', 'world', 'economy', 'worsen', 'respondent', 'also', 'say', 'national', 'economy', 'get', 'bad', 'ask', 'family', 'financial', 'outlook', 'majority', 'country', 'say', 'positive', 'future', 'almost', 'people', 'country', 'question', 'poll', 'mostly', 'conduct', 'asian_tsunami_disaster', 'poll', 'find', 'majority', 'plurality', 'people', 'country', 'believe', 'economy', 'go', 'downhill', 'compare', 'respondent', 'country', 'believe', 'improve', 'survey', 'country', 'split', 'percentage', 'term', 'average', 'respondent', 'country', 'say', 'world', 'economy', 'get', 'bad', 'compare', 'say', 'improve', 'similarly', 'pessimistic', 'national', 'economy', 'optimistic', 'see', 'family', 'economic_condition', 'improve', 'say', 'get', 'bad', 'poll', 'people', 'conduct', 'international', 'polling', 'firm', 'together', 'program', 'international', 'policy', 'attitude', 'economy', 'pick', 'difficult', 'time', 'people', 'seem', 'fully', 'absorb', 'development', 'personally', 'experience', 'effect', 'say', 'people', 'world', 'say', 'world', 'may', 'perception', 'war', 'terrorism', 'religious', 'political', 'division', 'make', 'world', 'bad', 'place', 'far', 'reflect', 'global', 'economic', 'performance', 'say', 'country', 'people', 'optimistic', 'world', 'family', 'fast', 'grow', 'develop', 'economy', 'follow', 'see', 'decade', 'blister', 'le ...
